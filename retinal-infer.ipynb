# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/retinal-metrices/xception.csv
# /kaggle/input/retinal-metrices/densenet.csv
# /kaggle/input/retinal-metrices/resnet.csv
# /kaggle/input/retinal-metrices/vgg.csv
# /kaggle/input/retinal-metrices/efficientnet.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the metrics from CSV files
xception_metrics = pd.read_csv('/kaggle/input/retinal-metrices/xception.csv')
densenet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/densenet.csv')
resnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/resnet.csv')
vgg_metrics = pd.read_csv('/kaggle/input/retinal-metrices/vgg.csv')
efficientnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/efficientnet.csv')

# Plotting validation loss for each model
plt.figure(figsize=(10, 6))

plt.plot(xception_metrics['loss'], label='Xception-CBAM-Skip', color='blue')
plt.plot(densenet_metrics['loss'], label='DenseNet-CBAM-Skip', color='green')
plt.plot(resnet_metrics['val_loss'], label='ResNet-CBAM-Skip', color='red')
plt.plot(vgg_metrics['val_loss'], label='VGG16-CBAM-Skip', color='purple')
plt.plot(efficientnet_metrics['val_loss'], label='EfficientNet-CBAM-Skip', color='orange')

# Adding titles and labels
plt.title('Validation Loss over Epochs for Different Models')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the metrics from CSV files
xception_metrics = pd.read_csv('/kaggle/input/retinal-metrices/xception.csv')
densenet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/densenet.csv')
resnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/resnet.csv')
vgg_metrics = pd.read_csv('/kaggle/input/retinal-metrices/vgg.csv')
efficientnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/efficientnet.csv')

# Plotting validation loss for each model
plt.figure(figsize=(10, 6))

plt.plot(xception_metrics['loss'], label='Xception-CBAM-Skip', linestyle='-', linewidth=1, color='blue', marker='o', alpha=0.8)
plt.plot(densenet_metrics['val_loss'], label='DenseNet-CBAM-Skip', linestyle='--', linewidth=1, color='green', marker='s', alpha=0.8)
plt.plot(resnet_metrics['val_loss'], label='ResNet-CBAM-Skip', linestyle='-.', linewidth=1, color='red', marker='^', alpha=0.8)
plt.plot(vgg_metrics['val_loss'], label='VGG16-CBAM-Skip', linestyle=':', linewidth=1, color='purple', marker='d', alpha=0.8)
plt.plot(efficientnet_metrics['val_loss'], label='EfficientNet-CBAM-Skip', linestyle='-', linewidth=1, color='orange', marker='x', alpha=0.8)

# Adding titles and labels
plt.title('Validation Loss over Epochs for Different Models')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the metrics from CSV files
xception_metrics = pd.read_csv('/kaggle/input/retinal-metrices/xception.csv')
densenet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/densenet.csv')
resnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/resnet.csv')
vgg_metrics = pd.read_csv('/kaggle/input/retinal-metrices/vgg.csv')
efficientnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/efficientnet.csv')

# Plotting validation accuracy for each model
plt.figure(figsize=(10, 6))

plt.plot(xception_metrics['accuracy'], label='Xception-CBAM-Skip', linestyle='-', linewidth=1, color='blue', marker='o', alpha=0.8)
plt.plot(densenet_metrics['val_accuracy'], label='DenseNet-CBAM-Skip', linestyle='--', linewidth=1, color='green', marker='s', alpha=0.8)
plt.plot(resnet_metrics['val_accuracy'], label='ResNet-CBAM-Skip', linestyle='-.', linewidth=1, color='red', marker='^', alpha=0.8)
plt.plot(vgg_metrics['val_accuracy'], label='VGG16-CBAM-Skip', linestyle=':', linewidth=1, color='purple', marker='d', alpha=0.8)
plt.plot(efficientnet_metrics['val_accuracy'], label='EfficientNet-CBAM-Skip', linestyle='-', linewidth=1, color='orange', marker='x', alpha=0.8)

# Adding titles and labels
plt.title('Validation Accuracy over Epochs for Different Models')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Set the style

# Set the style
plt.style.use('seaborn-whitegrid')
# Load the metrics from CSV files
xception_metrics = pd.read_csv('/kaggle/input/retinal-metrices/xception.csv')
densenet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/densenet.csv')
resnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/resnet.csv')
vgg_metrics = pd.read_csv('/kaggle/input/retinal-metrices/vgg.csv')
efficientnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/efficientnet.csv')

# Plotting validation accuracy for each model
plt.figure(figsize=(10, 6))

plt.plot(xception_metrics['accuracy'], label='Xception-CBAM-Skip', linestyle='-', linewidth=2, color='blue')
plt.plot(densenet_metrics['val_accuracy'], label='DenseNet-CBAM-Skip', linestyle='--', linewidth=2, color='green')
plt.plot(resnet_metrics['val_accuracy'], label='ResNet-CBAM-Skip', linestyle='-.', linewidth=2, color='red')
plt.plot(vgg_metrics['val_accuracy'], label='VGG16-CBAM-Skip', linestyle=':', linewidth=2, color='purple')
plt.plot(efficientnet_metrics['val_accuracy'], label='EfficientNet-CBAM-Skip', linestyle='-', linewidth=2, color='orange')

# Adding titles and labels
plt.title('Validation Accuracy over Epochs for Tested Models', fontsize= 10)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Validation Accuracy', fontsize=14)

# Adding grid
plt.grid(True)

# Adding legend
plt.legend(loc='best', fontsize=12)

plt.savefig('/kaggle/working/accuracy_curve.png', dpi = 1000)
# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_18/199422654.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the style
plt.style.use('seaborn-whitegrid')

# Load the metrics from CSV files
xception_metrics = pd.read_csv('/kaggle/input/retinal-metrices/xception.csv')
densenet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/densenet.csv')
resnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/resnet.csv')
vgg_metrics = pd.read_csv('/kaggle/input/retinal-metrices/vgg.csv')
efficientnet_metrics = pd.read_csv('/kaggle/input/retinal-metrices/efficientnet.csv')

# Plotting validation loss for each model
plt.figure(figsize=(10, 6))

plt.plot(xception_metrics['loss'], label='Xception-CBAM-Skip', linestyle='-', linewidth=2, color='blue')
plt.plot(densenet_metrics['val_loss'], label='DenseNet-CBAM-Skip', linestyle='--', linewidth=2, color='green')
plt.plot(resnet_metrics['val_loss'], label='ResNet-CBAM-Skip', linestyle='-.', linewidth=2, color='red')
plt.plot(vgg_metrics['val_loss'], label='VGG16-CBAM-Skip', linestyle=':', linewidth=2, color='purple')
plt.plot(efficientnet_metrics['val_loss'], label='EfficientNet-CBAM-Skip', linestyle='-', linewidth=2, color='orange')

# Adding titles and labels
plt.title('Validation Loss over Epochs for Tested Models', fontsize=10)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Validation Loss', fontsize=14)

# Adding grid
plt.grid(True)

# Adding legend
plt.legend(loc='best', fontsize=12)

# Save the plot
plt.savefig('/kaggle/working/loss_curve.png', dpi=1000)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_18/3247962812.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
